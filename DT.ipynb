# %%
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
import matplotlib.pyplot as plt

# %%
data=load_breast_cancer()
X=data.data
Y=data.target
Xtrain,Xtest,Ytrain,Ytest=train_test_split(X,Y,test_size=0.2,random_state=42)
clf=DecisionTreeClassifier(criterion='entropy',max_depth=2)
clf.fit(X,Y)
Ypredict=clf.predict(Xtest)
accuracy=accuracy_score(Ytest,Ypredict)
print("Accuracy:",accuracy*100)
print("Sample\t\tPrediction\t\tActual\t\tPredicted")
for i in range(len(Ytest)):
    if Ypredict[i]==Ytest[i]:
        print(i+1,'\t\tCorrect Prediction\t',Ytest[i],'\t\t',Ypredict[i])
    else:
        print(i+1,'\t\tWrong Prediction\t',Ytest[i],'\t\t',Ypredict[i])
plt.figure(figsize=(10, 10)) 
tree.plot_tree(clf,filled=True)
plt.title("Decision Tree Vizualization")
plt.show()
# Out:
# Accuracy: 95.6140350877193
# Sample		Prediction		Actual		Predicted
# 1 		Correct Prediction	 1 		 1
# 2 		Correct Prediction	 0 		 0
# 3 		Correct Prediction	 0 		 0
# 4 		Correct Prediction	 1 		 1
# 5 		Correct Prediction	 1 		 1
# 6 		Correct Prediction	 0 		 0
# 7 		Correct Prediction	 0 		 0
# 8 		Correct Prediction	 0 		 0
# 9 		Wrong Prediction	 1 		 0
# 10 		Correct Prediction	 1 		 1
# 11 		Correct Prediction	 1 		 1
# 12 		Correct Prediction	 0 		 0
# 13 		Correct Prediction	 1 		 1
# 14 		Correct Prediction	 0 		 0
# 15 		Correct Prediction	 1 		 1
# 16 		Correct Prediction	 0 		 0
# 17 		Correct Prediction	 1 		 1
# 18 		Correct Prediction	 1 		 1
# 19 		Correct Prediction	 1 		 1
# 20 		Correct Prediction	 0 		 0
# 21 		Correct Prediction	 0 		 0
# 22 		Correct Prediction	 1 		 1
# 23 		Correct Prediction	 0 		 0
# 24 		Correct Prediction	 1 		 1
# 25 		Correct Prediction	 1 		 1
# 26 		Correct Prediction	 1 		 1
# 27 		Correct Prediction	 1 		 1
# 28 		Correct Prediction	 1 		 1
# 29 		Correct Prediction	 1 		 1
# 30 		Correct Prediction	 0 		 0
# 31 		Correct Prediction	 1 		 1
# 32 		Correct Prediction	 1 		 1
# 33 		Correct Prediction	 1 		 1
# 34 		Correct Prediction	 1 		 1
# 35 		Correct Prediction	 1 		 1
# 36 		Correct Prediction	 1 		 1
# 37 		Correct Prediction	 0 		 0
# 38 		Correct Prediction	 1 		 1
# 39 		Correct Prediction	 0 		 0
# 40 		Correct Prediction	 1 		 1
# 41 		Correct Prediction	 1 		 1
# 42 		Correct Prediction	 0 		 0
# 43 		Correct Prediction	 1 		 1
# 44 		Correct Prediction	 1 		 1
# 45 		Correct Prediction	 1 		 1
# 46 		Correct Prediction	 1 		 1
# 47 		Correct Prediction	 1 		 1
# 48 		Correct Prediction	 1 		 1
# 49 		Correct Prediction	 1 		 1
# 50 		Correct Prediction	 1 		 1
# 51 		Correct Prediction	 0 		 0
# 52 		Correct Prediction	 0 		 0
# 53 		Correct Prediction	 1 		 1
# 54 		Correct Prediction	 1 		 1
# 55 		Correct Prediction	 1 		 1
# 56 		Correct Prediction	 1 		 1
# 57 		Correct Prediction	 1 		 1
# 58 		Correct Prediction	 0 		 0
# 59 		Correct Prediction	 0 		 0
# 60 		Correct Prediction	 1 		 1
# 61 		Correct Prediction	 1 		 1
# 62 		Correct Prediction	 0 		 0
# 63 		Correct Prediction	 0 		 0
# 64 		Correct Prediction	 1 		 1
# 65 		Correct Prediction	 1 		 1
# 66 		Correct Prediction	 1 		 1
# 67 		Correct Prediction	 0 		 0
# 68 		Correct Prediction	 0 		 0
# 69 		Correct Prediction	 1 		 1
# 70 		Correct Prediction	 1 		 1
# 71 		Correct Prediction	 0 		 0
# 72 		Correct Prediction	 0 		 0
# 73 		Correct Prediction	 1 		 1
# 74 		Correct Prediction	 0 		 0
# 75 		Correct Prediction	 1 		 1
# 76 		Correct Prediction	 1 		 1
# 77 		Correct Prediction	 1 		 1
# 78 		Correct Prediction	 0 		 0
# 79 		Correct Prediction	 1 		 1
# 80 		Correct Prediction	 1 		 1
# 81 		Correct Prediction	 0 		 0
# 82 		Correct Prediction	 1 		 1
# 83 		Correct Prediction	 0 		 0
# 84 		Correct Prediction	 0 		 0
# 85 		Correct Prediction	 0 		 0
# 86 		Correct Prediction	 0 		 0
# 87 		Correct Prediction	 0 		 0
# 88 		Correct Prediction	 0 		 0
# 89 		Correct Prediction	 1 		 1
# 90 		Correct Prediction	 1 		 1
# 91 		Correct Prediction	 1 		 1
# 92 		Wrong Prediction	 1 		 0
# 93 		Wrong Prediction	 1 		 0
# 94 		Correct Prediction	 1 		 1
# 95 		Correct Prediction	 1 		 1
# 96 		Correct Prediction	 1 		 1
# 97 		Correct Prediction	 0 		 0
# 98 		Correct Prediction	 0 		 0
# 99 		Correct Prediction	 1 		 1
# 100 		Correct Prediction	 0 		 0
# 101 		Correct Prediction	 0 		 0
# 102 		Correct Prediction	 1 		 1
# 103 		Correct Prediction	 0 		 0
# 104 		Correct Prediction	 0 		 0
# 105 		Correct Prediction	 1 		 1
# 106 		Correct Prediction	 1 		 1
# 107 		Correct Prediction	 1 		 1
# 108 		Correct Prediction	 0 		 0
# 109 		Wrong Prediction	 1 		 0
# 110 		Wrong Prediction	 1 		 0
# 111 		Correct Prediction	 0 		 0
# 112 		Correct Prediction	 1 		 1
# 113 		Correct Prediction	 1 		 1
# 114 		Correct Prediction	 0 		 0
